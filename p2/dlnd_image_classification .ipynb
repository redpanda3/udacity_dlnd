# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    from sklearn import preprocessing
    enc = preprocessing.OneHotEncoder(n_values=10)
   
    
    return (np.array(enc.fit_transform(np.array(x).reshape(-1,1)).toarray()))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    
    return tf.placeholder(tf.float32,name='x',shape=[None, image_shape[0], image_shape[1], image_shape[2]])  

    

    
    


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function

    return tf.placeholder(tf.float32,shape=[None,n_classes],name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    weight=tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1], x_tensor.get_shape().as_list()[3],conv_num_outputs],stddev=0.3))
    bias=tf.Variable(tf.truncated_normal([conv_num_outputs],stddev=0.3))
    x = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x = tf.nn.bias_add(x, bias)
    x = tf.nn.relu(x)
    x = tf.nn.max_pool( x, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    
    
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    

    x=tf.reshape(x_tensor,[-1,x_tensor.get_shape().as_list()[1]*x_tensor.get_shape().as_list()[2]*x_tensor.get_shape().as_list()[3]])


    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x = tf.contrib.layers.fully_connected(inputs=x_tensor,num_outputs=num_outputs,activation_fn=tf.nn.relu)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x = tf.contrib.layers.fully_connected(inputs=x_tensor,num_outputs=num_outputs,activation_fn=None)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:

    pool_ksize=[2,2]
    pool_strides=[2,2]
    x=conv2d_maxpool(x, 13, [2,2], [1,1], pool_ksize, pool_strides)

    x=conv2d_maxpool(x, 26, [2,2], [1,1], pool_ksize, pool_strides)


    
    x=conv2d_maxpool(x, 32, [2,2], [1,1], pool_ksize, pool_strides)


   

    
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    x = flatten(x)
    
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    x = fully_conn(x, 40)
    x = tf.nn.dropout(x, keep_prob)

    
    x = fully_conn(x, 64)
    x = tf.nn.dropout(x, keep_prob)






    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    x= output(x, 10)
    
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    
    # TODO: Implement Function
    
    loss= session.run(cost, feed_dict={x:feature_batch, y:label_batch,keep_prob:1.0})
    print ("loss: ",loss)
    validation_accuracy=session.run(accuracy, feed_dict={x:valid_features,y:valid_labels,keep_prob:1.0})
    print ("validation_accuracy: ",validation_accuracy)

    return None

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 80
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.11625
# validation_accuracy:  0.2734
# Epoch  2, CIFAR-10 Batch 1:  loss:  1.99246
# validation_accuracy:  0.3094
# Epoch  3, CIFAR-10 Batch 1:  loss:  1.89412
# validation_accuracy:  0.3192
# Epoch  4, CIFAR-10 Batch 1:  loss:  1.84794
# validation_accuracy:  0.3318
# Epoch  5, CIFAR-10 Batch 1:  loss:  1.74689
# validation_accuracy:  0.3432
# Epoch  6, CIFAR-10 Batch 1:  loss:  1.69321
# validation_accuracy:  0.3636
# Epoch  7, CIFAR-10 Batch 1:  loss:  1.63996
# validation_accuracy:  0.3714
# Epoch  8, CIFAR-10 Batch 1:  loss:  1.62463
# validation_accuracy:  0.3794
# Epoch  9, CIFAR-10 Batch 1:  loss:  1.54552
# validation_accuracy:  0.3962
# Epoch 10, CIFAR-10 Batch 1:  loss:  1.48017
# validation_accuracy:  0.4044
# Epoch 11, CIFAR-10 Batch 1:  loss:  1.44083
# validation_accuracy:  0.4102
# Epoch 12, CIFAR-10 Batch 1:  loss:  1.40233
# validation_accuracy:  0.4164
# Epoch 13, CIFAR-10 Batch 1:  loss:  1.35076
# validation_accuracy:  0.4212
# Epoch 14, CIFAR-10 Batch 1:  loss:  1.34281
# validation_accuracy:  0.4132
# Epoch 15, CIFAR-10 Batch 1:  loss:  1.32519
# validation_accuracy:  0.4248
# Epoch 16, CIFAR-10 Batch 1:  loss:  1.27067
# validation_accuracy:  0.435
# Epoch 17, CIFAR-10 Batch 1:  loss:  1.27895
# validation_accuracy:  0.4388
# Epoch 18, CIFAR-10 Batch 1:  loss:  1.26304
# validation_accuracy:  0.4174
# Epoch 19, CIFAR-10 Batch 1:  loss:  1.22345
# validation_accuracy:  0.426
# Epoch 20, CIFAR-10 Batch 1:  loss:  1.23491
# validation_accuracy:  0.4322
# Epoch 21, CIFAR-10 Batch 1:  loss:  1.18089
# validation_accuracy:  0.424
# Epoch 22, CIFAR-10 Batch 1:  loss:  1.18696
# validation_accuracy:  0.4348
# Epoch 23, CIFAR-10 Batch 1:  loss:  1.13801
# validation_accuracy:  0.4322
# Epoch 24, CIFAR-10 Batch 1:  loss:  1.14546
# validation_accuracy:  0.4244
# Epoch 25, CIFAR-10 Batch 1:  loss:  1.08966
# validation_accuracy:  0.4446
# Epoch 26, CIFAR-10 Batch 1:  loss:  1.05557
# validation_accuracy:  0.4442
# Epoch 27, CIFAR-10 Batch 1:  loss:  1.06828
# validation_accuracy:  0.4434
# Epoch 28, CIFAR-10 Batch 1:  loss:  1.06313
# validation_accuracy:  0.4322
# Epoch 29, CIFAR-10 Batch 1:  loss:  1.01599
# validation_accuracy:  0.456
# Epoch 30, CIFAR-10 Batch 1:  loss:  1.02635
# validation_accuracy:  0.4372
# Epoch 31, CIFAR-10 Batch 1:  loss:  0.963861
# validation_accuracy:  0.457
# Epoch 32, CIFAR-10 Batch 1:  loss:  0.964646
# validation_accuracy:  0.4542
# Epoch 33, CIFAR-10 Batch 1:  loss:  0.924232
# validation_accuracy:  0.4534
# Epoch 34, CIFAR-10 Batch 1:  loss:  0.900671
# validation_accuracy:  0.4548
# Epoch 35, CIFAR-10 Batch 1:  loss:  0.956073
# validation_accuracy:  0.4588
# Epoch 36, CIFAR-10 Batch 1:  loss:  0.911499
# validation_accuracy:  0.4498
# Epoch 37, CIFAR-10 Batch 1:  loss:  0.885974
# validation_accuracy:  0.4548
# Epoch 38, CIFAR-10 Batch 1:  loss:  0.884259
# validation_accuracy:  0.4538
# Epoch 39, CIFAR-10 Batch 1:  loss:  0.874352
# validation_accuracy:  0.4536
# Epoch 40, CIFAR-10 Batch 1:  loss:  0.847215
# validation_accuracy:  0.4556
# Epoch 41, CIFAR-10 Batch 1:  loss:  0.86522
# validation_accuracy:  0.452
# Epoch 42, CIFAR-10 Batch 1:  loss:  0.877665
# validation_accuracy:  0.4462
# Epoch 43, CIFAR-10 Batch 1:  loss:  0.844277
# validation_accuracy:  0.4574
# Epoch 44, CIFAR-10 Batch 1:  loss:  0.813411
# validation_accuracy:  0.457
# Epoch 45, CIFAR-10 Batch 1:  loss:  0.820091
# validation_accuracy:  0.4506
# Epoch 46, CIFAR-10 Batch 1:  loss:  0.811649
# validation_accuracy:  0.4528
# Epoch 47, CIFAR-10 Batch 1:  loss:  0.783929
# validation_accuracy:  0.454
# Epoch 48, CIFAR-10 Batch 1:  loss:  0.776948
# validation_accuracy:  0.4508
# Epoch 49, CIFAR-10 Batch 1:  loss:  0.771489
# validation_accuracy:  0.46
# Epoch 50, CIFAR-10 Batch 1:  loss:  0.744887
# validation_accuracy:  0.4518
# Epoch 51, CIFAR-10 Batch 1:  loss:  0.75928
# validation_accuracy:  0.4452
# Epoch 52, CIFAR-10 Batch 1:  loss:  0.760705
# validation_accuracy:  0.449
# Epoch 53, CIFAR-10 Batch 1:  loss:  0.725249
# validation_accuracy:  0.4452
# Epoch 54, CIFAR-10 Batch 1:  loss:  0.715874
# validation_accuracy:  0.4582
# Epoch 55, CIFAR-10 Batch 1:  loss:  0.75558
# validation_accuracy:  0.4536
# Epoch 56, CIFAR-10 Batch 1:  loss:  0.736405
# validation_accuracy:  0.4488
# Epoch 57, CIFAR-10 Batch 1:  loss:  0.722589
# validation_accuracy:  0.4552
# Epoch 58, CIFAR-10 Batch 1:  loss:  0.716817
# validation_accuracy:  0.4526
# Epoch 59, CIFAR-10 Batch 1:  loss:  0.720783
# validation_accuracy:  0.4452
# Epoch 60, CIFAR-10 Batch 1:  loss:  0.698001
# validation_accuracy:  0.4566
# Epoch 61, CIFAR-10 Batch 1:  loss:  0.685216
# validation_accuracy:  0.4556
# Epoch 62, CIFAR-10 Batch 1:  loss:  0.701572
# validation_accuracy:  0.4504
# Epoch 63, CIFAR-10 Batch 1:  loss:  0.687532
# validation_accuracy:  0.453
# Epoch 64, CIFAR-10 Batch 1:  loss:  0.6931
# validation_accuracy:  0.4436
# Epoch 65, CIFAR-10 Batch 1:  loss:  0.68622
# validation_accuracy:  0.4494
# Epoch 66, CIFAR-10 Batch 1:  loss:  0.630572
# validation_accuracy:  0.4536
# Epoch 67, CIFAR-10 Batch 1:  loss:  0.641129
# validation_accuracy:  0.4436
# Epoch 68, CIFAR-10 Batch 1:  loss:  0.674256
# validation_accuracy:  0.447
# Epoch 69, CIFAR-10 Batch 1:  loss:  0.662251
# validation_accuracy:  0.4348
# Epoch 70, CIFAR-10 Batch 1:  loss:  0.668789
# validation_accuracy:  0.4366
# Epoch 71, CIFAR-10 Batch 1:  loss:  0.650214
# validation_accuracy:  0.443
# Epoch 72, CIFAR-10 Batch 1:  loss:  0.651767
# validation_accuracy:  0.4334
# Epoch 73, CIFAR-10 Batch 1:  loss:  0.610611
# validation_accuracy:  0.4488
# Epoch 74, CIFAR-10 Batch 1:  loss:  0.625182
# validation_accuracy:  0.4428
# Epoch 75, CIFAR-10 Batch 1:  loss:  0.58674
# validation_accuracy:  0.4466
# Epoch 76, CIFAR-10 Batch 1:  loss:  0.603131
# validation_accuracy:  0.4412
# Epoch 77, CIFAR-10 Batch 1:  loss:  0.586903
# validation_accuracy:  0.4492
# Epoch 78, CIFAR-10 Batch 1:  loss:  0.618666
# validation_accuracy:  0.441
# Epoch 79, CIFAR-10 Batch 1:  loss:  0.601289
# validation_accuracy:  0.44
# Epoch 80, CIFAR-10 Batch 1:  loss:  0.579751
# validation_accuracy:  0.4426

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.1804
# validation_accuracy:  0.195
# Epoch  1, CIFAR-10 Batch 2:  loss:  1.99448
# validation_accuracy:  0.2582
# Epoch  1, CIFAR-10 Batch 3:  loss:  1.69711
# validation_accuracy:  0.289
# Epoch  1, CIFAR-10 Batch 4:  loss:  1.85435
# validation_accuracy:  0.3122
# Epoch  1, CIFAR-10 Batch 5:  loss:  1.85649
# validation_accuracy:  0.3366
# Epoch  2, CIFAR-10 Batch 1:  loss:  1.87822
# validation_accuracy:  0.3386
# Epoch  2, CIFAR-10 Batch 2:  loss:  1.67584
# validation_accuracy:  0.352
# Epoch  2, CIFAR-10 Batch 3:  loss:  1.41897
# validation_accuracy:  0.3656
# Epoch  2, CIFAR-10 Batch 4:  loss:  1.64716
# validation_accuracy:  0.3684
# Epoch  2, CIFAR-10 Batch 5:  loss:  1.72889
# validation_accuracy:  0.382
# Epoch  3, CIFAR-10 Batch 1:  loss:  1.72433
# validation_accuracy:  0.3682
# Epoch  3, CIFAR-10 Batch 2:  loss:  1.52212
# validation_accuracy:  0.3922
# Epoch  3, CIFAR-10 Batch 3:  loss:  1.31796
# validation_accuracy:  0.3978
# Epoch  3, CIFAR-10 Batch 4:  loss:  1.51787
# validation_accuracy:  0.3976
# Epoch  3, CIFAR-10 Batch 5:  loss:  1.65431
# validation_accuracy:  0.4062
# Epoch  4, CIFAR-10 Batch 1:  loss:  1.59625
# validation_accuracy:  0.4082
# Epoch  4, CIFAR-10 Batch 2:  loss:  1.41892
# validation_accuracy:  0.4118
# Epoch  4, CIFAR-10 Batch 3:  loss:  1.31961
# validation_accuracy:  0.4222
# Epoch  4, CIFAR-10 Batch 4:  loss:  1.48747
# validation_accuracy:  0.4178
# Epoch  4, CIFAR-10 Batch 5:  loss:  1.65337
# validation_accuracy:  0.4184
# Epoch  5, CIFAR-10 Batch 1:  loss:  1.48704
# validation_accuracy:  0.4274
# Epoch  5, CIFAR-10 Batch 2:  loss:  1.39506
# validation_accuracy:  0.4342
# Epoch  5, CIFAR-10 Batch 3:  loss:  1.27073
# validation_accuracy:  0.4298
# Epoch  5, CIFAR-10 Batch 4:  loss:  1.45019
# validation_accuracy:  0.4334
# Epoch  5, CIFAR-10 Batch 5:  loss:  1.62348
# validation_accuracy:  0.4302
# Epoch  6, CIFAR-10 Batch 1:  loss:  1.47162
# validation_accuracy:  0.4362
# Epoch  6, CIFAR-10 Batch 2:  loss:  1.3304
# validation_accuracy:  0.4436
# Epoch  6, CIFAR-10 Batch 3:  loss:  1.30176
# validation_accuracy:  0.439
# Epoch  6, CIFAR-10 Batch 4:  loss:  1.44264
# validation_accuracy:  0.4512
# Epoch  6, CIFAR-10 Batch 5:  loss:  1.57114
# validation_accuracy:  0.4504
# Epoch  7, CIFAR-10 Batch 1:  loss:  1.41985
# validation_accuracy:  0.4508
# Epoch  7, CIFAR-10 Batch 2:  loss:  1.27448
# validation_accuracy:  0.455
# Epoch  7, CIFAR-10 Batch 3:  loss:  1.23968
# validation_accuracy:  0.4476
# Epoch  7, CIFAR-10 Batch 4:  loss:  1.41385
# validation_accuracy:  0.457
# Epoch  7, CIFAR-10 Batch 5:  loss:  1.57563
# validation_accuracy:  0.4612
# Epoch  8, CIFAR-10 Batch 1:  loss:  1.43876
# validation_accuracy:  0.456
# Epoch  8, CIFAR-10 Batch 2:  loss:  1.2592
# validation_accuracy:  0.46
# Epoch  8, CIFAR-10 Batch 3:  loss:  1.22942
# validation_accuracy:  0.4574
# Epoch  8, CIFAR-10 Batch 4:  loss:  1.40472
# validation_accuracy:  0.4692
# Epoch  8, CIFAR-10 Batch 5:  loss:  1.53446
# validation_accuracy:  0.4594
# Epoch  9, CIFAR-10 Batch 1:  loss:  1.42926
# validation_accuracy:  0.4546
# Epoch  9, CIFAR-10 Batch 2:  loss:  1.24185
# validation_accuracy:  0.4642
# Epoch  9, CIFAR-10 Batch 3:  loss:  1.20718
# validation_accuracy:  0.4688
# Epoch  9, CIFAR-10 Batch 4:  loss:  1.36398
# validation_accuracy:  0.4738
# Epoch  9, CIFAR-10 Batch 5:  loss:  1.4768
# validation_accuracy:  0.4732
# Epoch 10, CIFAR-10 Batch 1:  loss:  1.41698
# validation_accuracy:  0.4748
# Epoch 10, CIFAR-10 Batch 2:  loss:  1.16729
# validation_accuracy:  0.471
# Epoch 10, CIFAR-10 Batch 3:  loss:  1.17802
# validation_accuracy:  0.4826
# Epoch 10, CIFAR-10 Batch 4:  loss:  1.34496
# validation_accuracy:  0.4794
# Epoch 10, CIFAR-10 Batch 5:  loss:  1.43275
# validation_accuracy:  0.4796
# Epoch 11, CIFAR-10 Batch 1:  loss:  1.40425
# validation_accuracy:  0.4722
# Epoch 11, CIFAR-10 Batch 2:  loss:  1.15809
# validation_accuracy:  0.4886
# Epoch 11, CIFAR-10 Batch 3:  loss:  1.20611
# validation_accuracy:  0.4782
# Epoch 11, CIFAR-10 Batch 4:  loss:  1.32855
# validation_accuracy:  0.47
# Epoch 11, CIFAR-10 Batch 5:  loss:  1.39353
# validation_accuracy:  0.4802
# Epoch 12, CIFAR-10 Batch 1:  loss:  1.37083
# validation_accuracy:  0.4856
# Epoch 12, CIFAR-10 Batch 2:  loss:  1.11493
# validation_accuracy:  0.48
# Epoch 12, CIFAR-10 Batch 3:  loss:  1.13947
# validation_accuracy:  0.4876
# Epoch 12, CIFAR-10 Batch 4:  loss:  1.26124
# validation_accuracy:  0.4804
# Epoch 12, CIFAR-10 Batch 5:  loss:  1.41524
# validation_accuracy:  0.4892
# Epoch 13, CIFAR-10 Batch 1:  loss:  1.33355
# validation_accuracy:  0.4948
# Epoch 13, CIFAR-10 Batch 2:  loss:  1.04471
# validation_accuracy:  0.4956
# Epoch 13, CIFAR-10 Batch 3:  loss:  1.12647
# validation_accuracy:  0.486
# Epoch 13, CIFAR-10 Batch 4:  loss:  1.24366
# validation_accuracy:  0.485
# Epoch 13, CIFAR-10 Batch 5:  loss:  1.35802
# validation_accuracy:  0.494
# Epoch 14, CIFAR-10 Batch 1:  loss:  1.41629
# validation_accuracy:  0.496
# Epoch 14, CIFAR-10 Batch 2:  loss:  1.06025
# validation_accuracy:  0.4968
# Epoch 14, CIFAR-10 Batch 3:  loss:  1.13428
# validation_accuracy:  0.4908
# Epoch 14, CIFAR-10 Batch 4:  loss:  1.21879
# validation_accuracy:  0.4918
# Epoch 14, CIFAR-10 Batch 5:  loss:  1.32181
# validation_accuracy:  0.4884
# Epoch 15, CIFAR-10 Batch 1:  loss:  1.33741
# validation_accuracy:  0.502
# Epoch 15, CIFAR-10 Batch 2:  loss:  1.03109
# validation_accuracy:  0.4948
# Epoch 15, CIFAR-10 Batch 3:  loss:  1.1008
# validation_accuracy:  0.4944
# Epoch 15, CIFAR-10 Batch 4:  loss:  1.20351
# validation_accuracy:  0.4894
# Epoch 15, CIFAR-10 Batch 5:  loss:  1.33633
# validation_accuracy:  0.4888
# Epoch 16, CIFAR-10 Batch 1:  loss:  1.34462
# validation_accuracy:  0.4992
# Epoch 16, CIFAR-10 Batch 2:  loss:  1.02359
# validation_accuracy:  0.5076
# Epoch 16, CIFAR-10 Batch 3:  loss:  1.12445
# validation_accuracy:  0.4906
# Epoch 16, CIFAR-10 Batch 4:  loss:  1.19894
# validation_accuracy:  0.4924
# Epoch 16, CIFAR-10 Batch 5:  loss:  1.31018
# validation_accuracy:  0.5002
# Epoch 17, CIFAR-10 Batch 1:  loss:  1.36057
# validation_accuracy:  0.5056
# Epoch 17, CIFAR-10 Batch 2:  loss:  1.00085
# validation_accuracy:  0.5142
# Epoch 17, CIFAR-10 Batch 3:  loss:  1.06525
# validation_accuracy:  0.5056
# Epoch 17, CIFAR-10 Batch 4:  loss:  1.18753
# validation_accuracy:  0.493
# Epoch 17, CIFAR-10 Batch 5:  loss:  1.27452
# validation_accuracy:  0.4974
# Epoch 18, CIFAR-10 Batch 1:  loss:  1.35594
# validation_accuracy:  0.512
# Epoch 18, CIFAR-10 Batch 2:  loss:  0.946719
# validation_accuracy:  0.5146
# Epoch 18, CIFAR-10 Batch 3:  loss:  1.08055
# validation_accuracy:  0.5116
# Epoch 18, CIFAR-10 Batch 4:  loss:  1.15543
# validation_accuracy:  0.4938
# Epoch 18, CIFAR-10 Batch 5:  loss:  1.26041
# validation_accuracy:  0.5008
# Epoch 19, CIFAR-10 Batch 1:  loss:  1.29423
# validation_accuracy:  0.5134
# Epoch 19, CIFAR-10 Batch 2:  loss:  0.944212
# validation_accuracy:  0.4998
# Epoch 19, CIFAR-10 Batch 3:  loss:  1.07873
# validation_accuracy:  0.5188
# Epoch 19, CIFAR-10 Batch 4:  loss:  1.13461
# validation_accuracy:  0.4994
# Epoch 19, CIFAR-10 Batch 5:  loss:  1.27957
# validation_accuracy:  0.505
# Epoch 20, CIFAR-10 Batch 1:  loss:  1.28534
# validation_accuracy:  0.51
# Epoch 20, CIFAR-10 Batch 2:  loss:  0.915068
# validation_accuracy:  0.5092
# Epoch 20, CIFAR-10 Batch 3:  loss:  1.0462
# validation_accuracy:  0.514
# Epoch 20, CIFAR-10 Batch 4:  loss:  1.10462
# validation_accuracy:  0.5076
# Epoch 20, CIFAR-10 Batch 5:  loss:  1.22245
# validation_accuracy:  0.5074
# Epoch 21, CIFAR-10 Batch 1:  loss:  1.2562
# validation_accuracy:  0.5174
# Epoch 21, CIFAR-10 Batch 2:  loss:  0.856797
# validation_accuracy:  0.513
# Epoch 21, CIFAR-10 Batch 3:  loss:  1.00339
# validation_accuracy:  0.5114
# Epoch 21, CIFAR-10 Batch 4:  loss:  1.0559
# validation_accuracy:  0.5106
# Epoch 21, CIFAR-10 Batch 5:  loss:  1.158
# validation_accuracy:  0.5188
# Epoch 22, CIFAR-10 Batch 1:  loss:  1.24624
# validation_accuracy:  0.5166
# Epoch 22, CIFAR-10 Batch 2:  loss:  0.861202
# validation_accuracy:  0.5136
# Epoch 22, CIFAR-10 Batch 3:  loss:  1.02116
# validation_accuracy:  0.511
# Epoch 22, CIFAR-10 Batch 4:  loss:  1.03566
# validation_accuracy:  0.5086
# Epoch 22, CIFAR-10 Batch 5:  loss:  1.15307
# validation_accuracy:  0.5166
# Epoch 23, CIFAR-10 Batch 1:  loss:  1.26485
# validation_accuracy:  0.5154
# Epoch 23, CIFAR-10 Batch 2:  loss:  0.877196
# validation_accuracy:  0.5234
# Epoch 23, CIFAR-10 Batch 3:  loss:  1.02905
# validation_accuracy:  0.5174
# Epoch 23, CIFAR-10 Batch 4:  loss:  1.01144
# validation_accuracy:  0.5256
# Epoch 23, CIFAR-10 Batch 5:  loss:  1.16578
# validation_accuracy:  0.5228
# Epoch 24, CIFAR-10 Batch 1:  loss:  1.25721
# validation_accuracy:  0.522
# Epoch 24, CIFAR-10 Batch 2:  loss:  0.858209
# validation_accuracy:  0.5194
# Epoch 24, CIFAR-10 Batch 3:  loss:  1.02395
# validation_accuracy:  0.5224
# Epoch 24, CIFAR-10 Batch 4:  loss:  1.01683
# validation_accuracy:  0.5112
# Epoch 24, CIFAR-10 Batch 5:  loss:  1.14308
# validation_accuracy:  0.5226
# Epoch 25, CIFAR-10 Batch 1:  loss:  1.26019
# validation_accuracy:  0.5214
# Epoch 25, CIFAR-10 Batch 2:  loss:  0.83755
# validation_accuracy:  0.518
# Epoch 25, CIFAR-10 Batch 3:  loss:  1.01633
# validation_accuracy:  0.5178
# Epoch 25, CIFAR-10 Batch 4:  loss:  0.9944
# validation_accuracy:  0.512
# Epoch 25, CIFAR-10 Batch 5:  loss:  1.18321
# validation_accuracy:  0.5174
# Epoch 26, CIFAR-10 Batch 1:  loss:  1.24489
# validation_accuracy:  0.5274
# Epoch 26, CIFAR-10 Batch 2:  loss:  0.830351
# validation_accuracy:  0.5152
# Epoch 26, CIFAR-10 Batch 3:  loss:  1.00517
# validation_accuracy:  0.5082
# Epoch 26, CIFAR-10 Batch 4:  loss:  0.987706
# validation_accuracy:  0.5144
# Epoch 26, CIFAR-10 Batch 5:  loss:  1.13413
# validation_accuracy:  0.5196
# Epoch 27, CIFAR-10 Batch 1:  loss:  1.24338
# validation_accuracy:  0.524
# Epoch 27, CIFAR-10 Batch 2:  loss:  0.861149
# validation_accuracy:  0.5174
# Epoch 27, CIFAR-10 Batch 3:  loss:  0.968916
# validation_accuracy:  0.5274
# Epoch 27, CIFAR-10 Batch 4:  loss:  0.993321
# validation_accuracy:  0.5104
# Epoch 27, CIFAR-10 Batch 5:  loss:  1.14225
# validation_accuracy:  0.5126
# Epoch 28, CIFAR-10 Batch 1:  loss:  1.24346
# validation_accuracy:  0.5268
# Epoch 28, CIFAR-10 Batch 2:  loss:  0.83152
# validation_accuracy:  0.521
# Epoch 28, CIFAR-10 Batch 3:  loss:  0.9877
# validation_accuracy:  0.5224
# Epoch 28, CIFAR-10 Batch 4:  loss:  0.960122
# validation_accuracy:  0.5178
# Epoch 28, CIFAR-10 Batch 5:  loss:  1.11706
# validation_accuracy:  0.521
# Epoch 29, CIFAR-10 Batch 1:  loss:  1.23993
# validation_accuracy:  0.5312
# Epoch 29, CIFAR-10 Batch 2:  loss:  0.85708
# validation_accuracy:  0.5242
# Epoch 29, CIFAR-10 Batch 3:  loss:  0.996685
# validation_accuracy:  0.527
# Epoch 29, CIFAR-10 Batch 4:  loss:  0.973765
# validation_accuracy:  0.5322
# Epoch 29, CIFAR-10 Batch 5:  loss:  1.08472
# validation_accuracy:  0.5194
# Epoch 30, CIFAR-10 Batch 1:  loss:  1.22767
# validation_accuracy:  0.5288
# Epoch 30, CIFAR-10 Batch 2:  loss:  0.810125
# validation_accuracy:  0.5256
# Epoch 30, CIFAR-10 Batch 3:  loss:  0.979463
# validation_accuracy:  0.5284
# Epoch 30, CIFAR-10 Batch 4:  loss:  0.949001
# validation_accuracy:  0.5214
# Epoch 30, CIFAR-10 Batch 5:  loss:  1.08561
# validation_accuracy:  0.525
# Epoch 31, CIFAR-10 Batch 1:  loss:  1.23248
# validation_accuracy:  0.5264
# Epoch 31, CIFAR-10 Batch 2:  loss:  0.795989
# validation_accuracy:  0.52
# Epoch 31, CIFAR-10 Batch 3:  loss:  0.968001
# validation_accuracy:  0.53
# Epoch 31, CIFAR-10 Batch 4:  loss:  0.946832
# validation_accuracy:  0.5148
# Epoch 31, CIFAR-10 Batch 5:  loss:  1.1122
# validation_accuracy:  0.5188
# Epoch 32, CIFAR-10 Batch 1:  loss:  1.16016
# validation_accuracy:  0.5282
# Epoch 32, CIFAR-10 Batch 2:  loss:  0.785494
# validation_accuracy:  0.5206
# Epoch 32, CIFAR-10 Batch 3:  loss:  0.9775
# validation_accuracy:  0.5266
# Epoch 32, CIFAR-10 Batch 4:  loss:  0.947157
# validation_accuracy:  0.5274
# Epoch 32, CIFAR-10 Batch 5:  loss:  1.11021
# validation_accuracy:  0.5246
# Epoch 33, CIFAR-10 Batch 1:  loss:  1.16341
# validation_accuracy:  0.5196
# Epoch 33, CIFAR-10 Batch 2:  loss:  0.787293
# validation_accuracy:  0.5272
# Epoch 33, CIFAR-10 Batch 3:  loss:  0.94496
# validation_accuracy:  0.5292
# Epoch 33, CIFAR-10 Batch 4:  loss:  0.935044
# validation_accuracy:  0.5306
# Epoch 33, CIFAR-10 Batch 5:  loss:  1.09488
# validation_accuracy:  0.518
# Epoch 34, CIFAR-10 Batch 1:  loss:  1.16781
# validation_accuracy:  0.53
# Epoch 34, CIFAR-10 Batch 2:  loss:  0.826157
# validation_accuracy:  0.5278
# Epoch 34, CIFAR-10 Batch 3:  loss:  0.951848
# validation_accuracy:  0.5282
# Epoch 34, CIFAR-10 Batch 4:  loss:  0.918181
# validation_accuracy:  0.5348
# Epoch 34, CIFAR-10 Batch 5:  loss:  1.10563
# validation_accuracy:  0.5212
# Epoch 35, CIFAR-10 Batch 1:  loss:  1.1288
# validation_accuracy:  0.5328
# Epoch 35, CIFAR-10 Batch 2:  loss:  0.775515
# validation_accuracy:  0.5352
# Epoch 35, CIFAR-10 Batch 3:  loss:  0.938132
# validation_accuracy:  0.5328
# Epoch 35, CIFAR-10 Batch 4:  loss:  0.890785
# validation_accuracy:  0.533
# Epoch 35, CIFAR-10 Batch 5:  loss:  1.1127
# validation_accuracy:  0.5112
# Epoch 36, CIFAR-10 Batch 1:  loss:  1.17056
# validation_accuracy:  0.534
# Epoch 36, CIFAR-10 Batch 2:  loss:  0.828816
# validation_accuracy:  0.5312
# Epoch 36, CIFAR-10 Batch 3:  loss:  0.941892
# validation_accuracy:  0.5238
# Epoch 36, CIFAR-10 Batch 4:  loss:  0.927183
# validation_accuracy:  0.5324
# Epoch 36, CIFAR-10 Batch 5:  loss:  1.10276
# validation_accuracy:  0.521
# Epoch 37, CIFAR-10 Batch 1:  loss:  1.0881
# validation_accuracy:  0.5318
# Epoch 37, CIFAR-10 Batch 2:  loss:  0.805509
# validation_accuracy:  0.5274
# Epoch 37, CIFAR-10 Batch 3:  loss:  0.886277
# validation_accuracy:  0.534
# Epoch 37, CIFAR-10 Batch 4:  loss:  0.936955
# validation_accuracy:  0.5372
# Epoch 37, CIFAR-10 Batch 5:  loss:  1.06231
# validation_accuracy:  0.5236
# Epoch 38, CIFAR-10 Batch 1:  loss:  1.11106
# validation_accuracy:  0.5352
# Epoch 38, CIFAR-10 Batch 2:  loss:  0.745433
# validation_accuracy:  0.532
# Epoch 38, CIFAR-10 Batch 3:  loss:  0.925541
# validation_accuracy:  0.5304
# Epoch 38, CIFAR-10 Batch 4:  loss:  0.880035
# validation_accuracy:  0.5314
# Epoch 38, CIFAR-10 Batch 5:  loss:  1.08542
# validation_accuracy:  0.533
# Epoch 39, CIFAR-10 Batch 1:  loss:  1.05788
# validation_accuracy:  0.5316
# Epoch 39, CIFAR-10 Batch 2:  loss:  0.746522
# validation_accuracy:  0.5298
# Epoch 39, CIFAR-10 Batch 3:  loss:  0.954782
# validation_accuracy:  0.5296
# Epoch 39, CIFAR-10 Batch 4:  loss:  0.908075
# validation_accuracy:  0.5298
# Epoch 39, CIFAR-10 Batch 5:  loss:  1.10067
# validation_accuracy:  0.5332
# Epoch 40, CIFAR-10 Batch 1:  loss:  1.08765
# validation_accuracy:  0.5296
# Epoch 40, CIFAR-10 Batch 2:  loss:  0.77368
# validation_accuracy:  0.5282
# Epoch 40, CIFAR-10 Batch 3:  loss:  0.953709
# validation_accuracy:  0.536
# Epoch 40, CIFAR-10 Batch 4:  loss:  0.850551
# validation_accuracy:  0.5314
# Epoch 40, CIFAR-10 Batch 5:  loss:  1.05472
# validation_accuracy:  0.5384
# Epoch 41, CIFAR-10 Batch 1:  loss:  1.09868
# validation_accuracy:  0.5338
# Epoch 41, CIFAR-10 Batch 2:  loss:  0.726182
# validation_accuracy:  0.5218
# Epoch 41, CIFAR-10 Batch 3:  loss:  0.928166
# validation_accuracy:  0.5384
# Epoch 41, CIFAR-10 Batch 4:  loss:  0.883658
# validation_accuracy:  0.5298
# Epoch 41, CIFAR-10 Batch 5:  loss:  1.05794
# validation_accuracy:  0.5342
# Epoch 42, CIFAR-10 Batch 1:  loss:  1.07853
# validation_accuracy:  0.5392
# Epoch 42, CIFAR-10 Batch 2:  loss:  0.739871
# validation_accuracy:  0.527
# Epoch 42, CIFAR-10 Batch 3:  loss:  0.916688
# validation_accuracy:  0.5388
# Epoch 42, CIFAR-10 Batch 4:  loss:  0.850784
# validation_accuracy:  0.5326
# Epoch 42, CIFAR-10 Batch 5:  loss:  1.06768
# validation_accuracy:  0.5336
# Epoch 43, CIFAR-10 Batch 1:  loss:  1.08698
# validation_accuracy:  0.5392
# Epoch 43, CIFAR-10 Batch 2:  loss:  0.708354
# validation_accuracy:  0.5362
# Epoch 43, CIFAR-10 Batch 3:  loss:  0.905368
# validation_accuracy:  0.5452
# Epoch 43, CIFAR-10 Batch 4:  loss:  0.828898
# validation_accuracy:  0.5338
# Epoch 43, CIFAR-10 Batch 5:  loss:  1.03751
# validation_accuracy:  0.5368
# Epoch 44, CIFAR-10 Batch 1:  loss:  1.06415
# validation_accuracy:  0.5316
# Epoch 44, CIFAR-10 Batch 2:  loss:  0.743199
# validation_accuracy:  0.535
# Epoch 44, CIFAR-10 Batch 3:  loss:  0.906527
# validation_accuracy:  0.5334
# Epoch 44, CIFAR-10 Batch 4:  loss:  0.875632
# validation_accuracy:  0.5302
# Epoch 44, CIFAR-10 Batch 5:  loss:  1.04016
# validation_accuracy:  0.5284
# Epoch 45, CIFAR-10 Batch 1:  loss:  1.07751
# validation_accuracy:  0.536
# Epoch 45, CIFAR-10 Batch 2:  loss:  0.742104
# validation_accuracy:  0.5406
# Epoch 45, CIFAR-10 Batch 3:  loss:  0.898873
# validation_accuracy:  0.537
# Epoch 45, CIFAR-10 Batch 4:  loss:  0.81839
# validation_accuracy:  0.5374
# Epoch 45, CIFAR-10 Batch 5:  loss:  1.00598
# validation_accuracy:  0.5396
# Epoch 46, CIFAR-10 Batch 1:  loss:  1.06204
# validation_accuracy:  0.5356
# Epoch 46, CIFAR-10 Batch 2:  loss:  0.719057
# validation_accuracy:  0.5342
# Epoch 46, CIFAR-10 Batch 3:  loss:  0.913668
# validation_accuracy:  0.5352
# Epoch 46, CIFAR-10 Batch 4:  loss:  0.824258
# validation_accuracy:  0.5286
# Epoch 46, CIFAR-10 Batch 5:  loss:  1.03281
# validation_accuracy:  0.531
# Epoch 47, CIFAR-10 Batch 1:  loss:  1.05609
# validation_accuracy:  0.5316
# Epoch 47, CIFAR-10 Batch 2:  loss:  0.696698
# validation_accuracy:  0.5424
# Epoch 47, CIFAR-10 Batch 3:  loss:  0.865961
# validation_accuracy:  0.536
# Epoch 47, CIFAR-10 Batch 4:  loss:  0.788408
# validation_accuracy:  0.5338
# Epoch 47, CIFAR-10 Batch 5:  loss:  1.02341
# validation_accuracy:  0.5318
# Epoch 48, CIFAR-10 Batch 1:  loss:  1.06921
# validation_accuracy:  0.5334
# Epoch 48, CIFAR-10 Batch 2:  loss:  0.691011
# validation_accuracy:  0.546
# Epoch 48, CIFAR-10 Batch 3:  loss:  0.917509
# validation_accuracy:  0.5352
# Epoch 48, CIFAR-10 Batch 4:  loss:  0.803473
# validation_accuracy:  0.5374
# Epoch 48, CIFAR-10 Batch 5:  loss:  0.99838
# validation_accuracy:  0.5398
# Epoch 49, CIFAR-10 Batch 1:  loss:  1.02495
# validation_accuracy:  0.5418
# Epoch 49, CIFAR-10 Batch 2:  loss:  0.709894
# validation_accuracy:  0.5334
# Epoch 49, CIFAR-10 Batch 3:  loss:  0.890455
# validation_accuracy:  0.5398
# Epoch 49, CIFAR-10 Batch 4:  loss:  0.790496
# validation_accuracy:  0.5336
# Epoch 49, CIFAR-10 Batch 5:  loss:  0.997207
# validation_accuracy:  0.5324
# Epoch 50, CIFAR-10 Batch 1:  loss:  1.03622
# validation_accuracy:  0.5332
# Epoch 50, CIFAR-10 Batch 2:  loss:  0.660742
# validation_accuracy:  0.5354
# Epoch 50, CIFAR-10 Batch 3:  loss:  0.881914
# validation_accuracy:  0.537
# Epoch 50, CIFAR-10 Batch 4:  loss:  0.819276
# validation_accuracy:  0.5306
# Epoch 50, CIFAR-10 Batch 5:  loss:  1.0478
# validation_accuracy:  0.5348
# Epoch 51, CIFAR-10 Batch 1:  loss:  1.03728
# validation_accuracy:  0.5394
# Epoch 51, CIFAR-10 Batch 2:  loss:  0.709234
# validation_accuracy:  0.5404
# Epoch 51, CIFAR-10 Batch 3:  loss:  0.856353
# validation_accuracy:  0.5444
# Epoch 51, CIFAR-10 Batch 4:  loss:  0.779126
# validation_accuracy:  0.526
# Epoch 51, CIFAR-10 Batch 5:  loss:  1.02626
# validation_accuracy:  0.526
# Epoch 52, CIFAR-10 Batch 1:  loss:  1.02815
# validation_accuracy:  0.5396
# Epoch 52, CIFAR-10 Batch 2:  loss:  0.689958
# validation_accuracy:  0.5214
# Epoch 52, CIFAR-10 Batch 3:  loss:  0.849037
# validation_accuracy:  0.537
# Epoch 52, CIFAR-10 Batch 4:  loss:  0.785027
# validation_accuracy:  0.5232
# Epoch 52, CIFAR-10 Batch 5:  loss:  1.00398
# validation_accuracy:  0.5338
# Epoch 53, CIFAR-10 Batch 1:  loss:  1.03551
# validation_accuracy:  0.5456
# Epoch 53, CIFAR-10 Batch 2:  loss:  0.684603
# validation_accuracy:  0.5464
# Epoch 53, CIFAR-10 Batch 3:  loss:  0.862477
# validation_accuracy:  0.5464
# Epoch 53, CIFAR-10 Batch 4:  loss:  0.767191
# validation_accuracy:  0.538
# Epoch 53, CIFAR-10 Batch 5:  loss:  1.00562
# validation_accuracy:  0.5398
# Epoch 54, CIFAR-10 Batch 1:  loss:  1.03604
# validation_accuracy:  0.5458
# Epoch 54, CIFAR-10 Batch 2:  loss:  0.694978
# validation_accuracy:  0.5422
# Epoch 54, CIFAR-10 Batch 3:  loss:  0.831801
# validation_accuracy:  0.5436
# Epoch 54, CIFAR-10 Batch 4:  loss:  0.777444
# validation_accuracy:  0.5314
# Epoch 54, CIFAR-10 Batch 5:  loss:  0.996333
# validation_accuracy:  0.5468
# Epoch 55, CIFAR-10 Batch 1:  loss:  1.02736
# validation_accuracy:  0.5396
# Epoch 55, CIFAR-10 Batch 2:  loss:  0.682658
# validation_accuracy:  0.5348
# Epoch 55, CIFAR-10 Batch 3:  loss:  0.872529
# validation_accuracy:  0.541
# Epoch 55, CIFAR-10 Batch 4:  loss:  0.759447
# validation_accuracy:  0.5358
# Epoch 55, CIFAR-10 Batch 5:  loss:  1.03361
# validation_accuracy:  0.5398
# Epoch 56, CIFAR-10 Batch 1:  loss:  1.0335
# validation_accuracy:  0.5414
# Epoch 56, CIFAR-10 Batch 2:  loss:  0.684312
# validation_accuracy:  0.5428
# Epoch 56, CIFAR-10 Batch 3:  loss:  0.914285
# validation_accuracy:  0.5368
# Epoch 56, CIFAR-10 Batch 4:  loss:  0.757216
# validation_accuracy:  0.5372
# Epoch 56, CIFAR-10 Batch 5:  loss:  0.983685
# validation_accuracy:  0.5396
# Epoch 57, CIFAR-10 Batch 1:  loss:  1.03306
# validation_accuracy:  0.542
# Epoch 57, CIFAR-10 Batch 2:  loss:  0.70889
# validation_accuracy:  0.5454
# Epoch 57, CIFAR-10 Batch 3:  loss:  0.871665
# validation_accuracy:  0.5406
# Epoch 57, CIFAR-10 Batch 4:  loss:  0.733905
# validation_accuracy:  0.539
# Epoch 57, CIFAR-10 Batch 5:  loss:  1.02311
# validation_accuracy:  0.5354
# Epoch 58, CIFAR-10 Batch 1:  loss:  1.02431
# validation_accuracy:  0.5336
# Epoch 58, CIFAR-10 Batch 2:  loss:  0.655686
# validation_accuracy:  0.5444
# Epoch 58, CIFAR-10 Batch 3:  loss:  0.838262
# validation_accuracy:  0.5502
# Epoch 58, CIFAR-10 Batch 4:  loss:  0.795213
# validation_accuracy:  0.5328
# Epoch 58, CIFAR-10 Batch 5:  loss:  1.01913
# validation_accuracy:  0.5342
# Epoch 59, CIFAR-10 Batch 1:  loss:  1.01078
# validation_accuracy:  0.538
# Epoch 59, CIFAR-10 Batch 2:  loss:  0.685703
# validation_accuracy:  0.5424
# Epoch 59, CIFAR-10 Batch 3:  loss:  0.862511
# validation_accuracy:  0.5446
# Epoch 59, CIFAR-10 Batch 4:  loss:  0.762964
# validation_accuracy:  0.538
# Epoch 59, CIFAR-10 Batch 5:  loss:  1.02605
# validation_accuracy:  0.5242
# Epoch 60, CIFAR-10 Batch 1:  loss:  1.00342
# validation_accuracy:  0.5484
# Epoch 60, CIFAR-10 Batch 2:  loss:  0.654157
# validation_accuracy:  0.539
# Epoch 60, CIFAR-10 Batch 3:  loss:  0.848004
# validation_accuracy:  0.5444
# Epoch 60, CIFAR-10 Batch 4:  loss:  0.761159
# validation_accuracy:  0.5374
# Epoch 60, CIFAR-10 Batch 5:  loss:  0.987482
# validation_accuracy:  0.5386
# Epoch 61, CIFAR-10 Batch 1:  loss:  0.999584
# validation_accuracy:  0.5416
# Epoch 61, CIFAR-10 Batch 2:  loss:  0.661256
# validation_accuracy:  0.5424
# Epoch 61, CIFAR-10 Batch 3:  loss:  0.809322
# validation_accuracy:  0.5406
# Epoch 61, CIFAR-10 Batch 4:  loss:  0.771299
# validation_accuracy:  0.5392
# Epoch 61, CIFAR-10 Batch 5:  loss:  0.953596
# validation_accuracy:  0.535
# Epoch 62, CIFAR-10 Batch 1:  loss:  0.984207
# validation_accuracy:  0.5404
# Epoch 62, CIFAR-10 Batch 2:  loss:  0.68514
# validation_accuracy:  0.5414
# Epoch 62, CIFAR-10 Batch 3:  loss:  0.839091
# validation_accuracy:  0.5356
# Epoch 62, CIFAR-10 Batch 4:  loss:  0.783215
# validation_accuracy:  0.5368
# Epoch 62, CIFAR-10 Batch 5:  loss:  0.977488
# validation_accuracy:  0.535
# Epoch 63, CIFAR-10 Batch 1:  loss:  0.970115
# validation_accuracy:  0.5422
# Epoch 63, CIFAR-10 Batch 2:  loss:  0.665648
# validation_accuracy:  0.5462
# Epoch 63, CIFAR-10 Batch 3:  loss:  0.837453
# validation_accuracy:  0.545
# Epoch 63, CIFAR-10 Batch 4:  loss:  0.766433
# validation_accuracy:  0.5434
# Epoch 63, CIFAR-10 Batch 5:  loss:  1.00177
# validation_accuracy:  0.543
# Epoch 64, CIFAR-10 Batch 1:  loss:  0.991954
# validation_accuracy:  0.546
# Epoch 64, CIFAR-10 Batch 2:  loss:  0.650547
# validation_accuracy:  0.5414
# Epoch 64, CIFAR-10 Batch 3:  loss:  0.822088
# validation_accuracy:  0.5442
# Epoch 64, CIFAR-10 Batch 4:  loss:  0.72108
# validation_accuracy:  0.54
# Epoch 64, CIFAR-10 Batch 5:  loss:  0.960506
# validation_accuracy:  0.5452
# Epoch 65, CIFAR-10 Batch 1:  loss:  0.973857
# validation_accuracy:  0.546
# Epoch 65, CIFAR-10 Batch 2:  loss:  0.677589
# validation_accuracy:  0.5508
# Epoch 65, CIFAR-10 Batch 3:  loss:  0.826456
# validation_accuracy:  0.5426
# Epoch 65, CIFAR-10 Batch 4:  loss:  0.741309
# validation_accuracy:  0.5384
# Epoch 65, CIFAR-10 Batch 5:  loss:  0.969047
# validation_accuracy:  0.5288
# Epoch 66, CIFAR-10 Batch 1:  loss:  0.974341
# validation_accuracy:  0.5444
# Epoch 66, CIFAR-10 Batch 2:  loss:  0.681128
# validation_accuracy:  0.5446
# Epoch 66, CIFAR-10 Batch 3:  loss:  0.826415
# validation_accuracy:  0.5444
# Epoch 66, CIFAR-10 Batch 4:  loss:  0.742448
# validation_accuracy:  0.5378
# Epoch 66, CIFAR-10 Batch 5:  loss:  0.970384
# validation_accuracy:  0.5376
# Epoch 67, CIFAR-10 Batch 1:  loss:  0.986883
# validation_accuracy:  0.543
# Epoch 67, CIFAR-10 Batch 2:  loss:  0.695283
# validation_accuracy:  0.5484
# Epoch 67, CIFAR-10 Batch 3:  loss:  0.816562
# validation_accuracy:  0.5364
# Epoch 67, CIFAR-10 Batch 4:  loss:  0.762798
# validation_accuracy:  0.5416
# Epoch 67, CIFAR-10 Batch 5:  loss:  0.963419
# validation_accuracy:  0.5346
# Epoch 68, CIFAR-10 Batch 1:  loss:  0.918152
# validation_accuracy:  0.5446
# Epoch 68, CIFAR-10 Batch 2:  loss:  0.680363
# validation_accuracy:  0.5432
# Epoch 68, CIFAR-10 Batch 3:  loss:  0.806999
# validation_accuracy:  0.544
# Epoch 68, CIFAR-10 Batch 4:  loss:  0.759383
# validation_accuracy:  0.5386
# Epoch 68, CIFAR-10 Batch 5:  loss:  0.990056
# validation_accuracy:  0.5382
# Epoch 69, CIFAR-10 Batch 1:  loss:  0.989568
# validation_accuracy:  0.5482
# Epoch 69, CIFAR-10 Batch 2:  loss:  0.658098
# validation_accuracy:  0.5448
# Epoch 69, CIFAR-10 Batch 3:  loss:  0.808762
# validation_accuracy:  0.5472
# Epoch 69, CIFAR-10 Batch 4:  loss:  0.759779
# validation_accuracy:  0.5338
# Epoch 69, CIFAR-10 Batch 5:  loss:  0.95493
# validation_accuracy:  0.5416
# Epoch 70, CIFAR-10 Batch 1:  loss:  0.960319
# validation_accuracy:  0.5416
# Epoch 70, CIFAR-10 Batch 2:  loss:  0.663972
# validation_accuracy:  0.547
# Epoch 70, CIFAR-10 Batch 3:  loss:  0.811523
# validation_accuracy:  0.5392
# Epoch 70, CIFAR-10 Batch 4:  loss:  0.773052
# validation_accuracy:  0.5316
# Epoch 70, CIFAR-10 Batch 5:  loss:  0.942406
# validation_accuracy:  0.5434
# Epoch 71, CIFAR-10 Batch 1:  loss:  0.965994
# validation_accuracy:  0.546
# Epoch 71, CIFAR-10 Batch 2:  loss:  0.645319
# validation_accuracy:  0.5398
# Epoch 71, CIFAR-10 Batch 3:  loss:  0.79428
# validation_accuracy:  0.5488
# Epoch 71, CIFAR-10 Batch 4:  loss:  0.727543
# validation_accuracy:  0.5408
# Epoch 71, CIFAR-10 Batch 5:  loss:  0.951792
# validation_accuracy:  0.5402
# Epoch 72, CIFAR-10 Batch 1:  loss:  0.989065
# validation_accuracy:  0.539
# Epoch 72, CIFAR-10 Batch 2:  loss:  0.635951
# validation_accuracy:  0.5482
# Epoch 72, CIFAR-10 Batch 3:  loss:  0.803965
# validation_accuracy:  0.542
# Epoch 72, CIFAR-10 Batch 4:  loss:  0.73091
# validation_accuracy:  0.5392
# Epoch 72, CIFAR-10 Batch 5:  loss:  0.937559
# validation_accuracy:  0.5376
# Epoch 73, CIFAR-10 Batch 1:  loss:  1.01548
# validation_accuracy:  0.5384
# Epoch 73, CIFAR-10 Batch 2:  loss:  0.642647
# validation_accuracy:  0.5416
# Epoch 73, CIFAR-10 Batch 3:  loss:  0.808326
# validation_accuracy:  0.5394
# Epoch 73, CIFAR-10 Batch 4:  loss:  0.70092
# validation_accuracy:  0.5396
# Epoch 73, CIFAR-10 Batch 5:  loss:  0.923232
# validation_accuracy:  0.5458
# Epoch 74, CIFAR-10 Batch 1:  loss:  0.958448
# validation_accuracy:  0.5458
# Epoch 74, CIFAR-10 Batch 2:  loss:  0.634959
# validation_accuracy:  0.5494
# Epoch 74, CIFAR-10 Batch 3:  loss:  0.804184
# validation_accuracy:  0.5428
# Epoch 74, CIFAR-10 Batch 4:  loss:  0.719727
# validation_accuracy:  0.5434
# Epoch 74, CIFAR-10 Batch 5:  loss:  0.966081
# validation_accuracy:  0.5382
# Epoch 75, CIFAR-10 Batch 1:  loss:  0.973333
# validation_accuracy:  0.5418
# Epoch 75, CIFAR-10 Batch 2:  loss:  0.674031
# validation_accuracy:  0.5514
# Epoch 75, CIFAR-10 Batch 3:  loss:  0.795021
# validation_accuracy:  0.5416
# Epoch 75, CIFAR-10 Batch 4:  loss:  0.721114
# validation_accuracy:  0.5422
# Epoch 75, CIFAR-10 Batch 5:  loss:  0.927593
# validation_accuracy:  0.5498
# Epoch 76, CIFAR-10 Batch 1:  loss:  0.919632
# validation_accuracy:  0.544
# Epoch 76, CIFAR-10 Batch 2:  loss:  0.625548
# validation_accuracy:  0.5486
# Epoch 76, CIFAR-10 Batch 3:  loss:  0.826089
# validation_accuracy:  0.545
# Epoch 76, CIFAR-10 Batch 4:  loss:  0.74525
# validation_accuracy:  0.5412
# Epoch 76, CIFAR-10 Batch 5:  loss:  0.947233
# validation_accuracy:  0.5328
# Epoch 77, CIFAR-10 Batch 1:  loss:  0.933823
# validation_accuracy:  0.5478
# Epoch 77, CIFAR-10 Batch 2:  loss:  0.650346
# validation_accuracy:  0.5436
# Epoch 77, CIFAR-10 Batch 3:  loss:  0.806601
# validation_accuracy:  0.537
# Epoch 77, CIFAR-10 Batch 4:  loss:  0.713436
# validation_accuracy:  0.5388
# Epoch 77, CIFAR-10 Batch 5:  loss:  0.933469
# validation_accuracy:  0.5416
# Epoch 78, CIFAR-10 Batch 1:  loss:  0.944353
# validation_accuracy:  0.548
# Epoch 78, CIFAR-10 Batch 2:  loss:  0.671544
# validation_accuracy:  0.5428
# Epoch 78, CIFAR-10 Batch 3:  loss:  0.798799
# validation_accuracy:  0.547
# Epoch 78, CIFAR-10 Batch 4:  loss:  0.700122
# validation_accuracy:  0.5388
# Epoch 78, CIFAR-10 Batch 5:  loss:  0.930444
# validation_accuracy:  0.5364
# Epoch 79, CIFAR-10 Batch 1:  loss:  0.886967
# validation_accuracy:  0.5472
# Epoch 79, CIFAR-10 Batch 2:  loss:  0.643431
# validation_accuracy:  0.5428
# Epoch 79, CIFAR-10 Batch 3:  loss:  0.794975
# validation_accuracy:  0.5438
# Epoch 79, CIFAR-10 Batch 4:  loss:  0.711284
# validation_accuracy:  0.5368
# Epoch 79, CIFAR-10 Batch 5:  loss:  0.903058
# validation_accuracy:  0.5392
# Epoch 80, CIFAR-10 Batch 1:  loss:  0.934443
# validation_accuracy:  0.5466
# Epoch 80, CIFAR-10 Batch 2:  loss:  0.655432
# validation_accuracy:  0.55
# Epoch 80, CIFAR-10 Batch 3:  loss:  0.788054
# validation_accuracy:  0.5448
# Epoch 80, CIFAR-10 Batch 4:  loss:  0.724497
# validation_accuracy:  0.5386
# Epoch 80, CIFAR-10 Batch 5:  loss:  0.888684
# validation_accuracy:  0.54

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5279865506329114

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
